# %% [markdown]
# # What is Ensambles?
# *  ensemble methods use multiple learning algorithms to obtain better predictive performance
# *  It is part of supervised ML

# %% [markdown]
# # What is Bootstrapped Agreegation(Bagging)?
# * Bootstrapping is a sampling technique in which we create subsets of observations from the original dataset, with replacement.
# *  The size of the subsets is the same as the size of the original set.
# *  Bagging (or Bootstrap Aggregating) technique uses these subsets (bags) to get a fair idea of the distribution (complete set)
# ![image20-768x289.png](data:image/png;base64,...)
#    *  Multiple subsets are created from the original dataset, selecting observations with replacement.
#    * A base model (weak model) is created on each of these subsets.
#    * The models run in parallel and are independent of each other.
#    * The final predictions are determined by combining the predictions from all the models
# ![Screenshot-from-2018-05-08-13-11-49-768x580.png](data:image/png;base64,...)

# %% [markdown]
# # What is Random Forest and explain the model?
# * Random forest is like bootstrapping algorithm with Decision tree (CART) model.
# * Say, we have 1000 observation in the complete population with 10 variables. Random forest tries to build multiple Decision Trees models with different samples and different initial variables.
# * For instance, it will take a random sample of 100 observation and 5 randomly chosen initial variables to build a CART model.
# * It will repeat the process (say) 10 times and then make a final prediction on each observation
# * Final prediction is a function of each prediction. This final prediction can simply be the mean of each prediction.

# %% [markdown]
# # Explain Random Forest ?
# * Random Forests are always referred to as black-box models
# * Random forests (RF) are basically a bag containing n Decision Trees (DT) having a different set of hyper-parameters
# *  trained on different subsets of data.
# * ![74060RF image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Explain about the Boosting
# * Boosting is a sequential process, where each subsequent model attempts to correct the errors of the previous model.
# * The succeeding models are dependent on the previous model.
# * Let’s understand the way boosting works in the below steps.
#    * A subset is created from the original dataset.
#    * Initially, all data points are given equal weights.
#    * A base model is created on this subset.
#    * This model is used to make predictions on the whole dataset
#    ![dd1-e1526989432375.png](data:image/png;base64,...)
#    * Errors are calculated using the actual values and predicted values.
#    * The observations which are incorrectly predicted, are given higher weights.
#    * (Here, the three misclassified blue-plus points will be given higher weights)
#    * Another model is created and predictions are made on the dataset.
# (This model tries to correct the errors from the previous model)
#  ![dd2-e1526989487878.png](data:image/png;base64,...)
#    * Similarly, multiple models are created, each correcting the errors of the previous model.
#    * The final model (strong learner) is the weighted mean of all the models (weak learners)
#    ![boosting10-300x205.png](data:image/png;base64,...)

# %% [markdown]
# # What is Loss Function?
# *n the context of an optimization algorithm, the function used to evaluate a candidate solution (i.e. a set of weights) is referred to as the objective function.
# * We may seek to maximize or minimize the objective function,
# * Depending upon the problem
# * Constains are given as well

# %% [markdown]
# # What is Residuals ?
# * Residuals in a statistical or machine learning model are the differences between observed and predicted values of data.
# * They are a diagnostic measure used when assessing the quality of a model.
# * They are also known as errors.

# %% [markdown]
# # What is Gradient Boosting?
# *  machine learning technique for regression and classification problems,
# *  which produces a prediction model in the form of an ensemble of weak prediction model,typically decision trees
# *  When a decision tree is the weak learner,
# *  the resulting algorithm is called gradient boosted trees, which usually outperforms random forest

# %% [markdown]
# # What is Regularization By Shrinkage?
# * Regularization:- Regularisation is a technique used to reduce the errors by fitting the function appropriately on the given training set and avoid overfitting.
# * One natural regularization parameter is the number of gradient boosting iterations M (i.e. the number of trees in the model when the base learner is a decision tree)
# * Increasing M reduces the error on training set, but setting it too high may lead to overfitting.
# * An optimal value of M is often selected by Cross Validation (CV)
# * Besides controlling M, several other regularization techniques are used.
# # Shrinkage
# * An important part of gradient boosting method is regularization by shrinkage which consists in modifying the update rule as follows:
# ![SharedScreenshot2.jpg](data:image/jpeg;base64,...)
# * where parameter v is called the "learning rate".
# * Empirically it has been found that using small learning rates (such as v< 0.1) yields dramatic improvements in models' generalization ability over gradient boosting without shrinking (v=1)
# *

# %% [markdown]
# # Explain about XGBoost ?
# * XGBoost is an ensemble learning method.
# * it may not be sufficient to rely upon the results of just one machine learning model.
# *  Ensemble learning offers a systematic solution to combine the predictive power of multiple learners.
# * The resultant is a single model which gives the aggregated output from several models.
# * The models that form the ensemble, also known as base learners, could be either from the same learning algorithm or different learning algorithms
# * Bagging and boosting are two widely used ensemble learners.
# # Bagging
# * Bagging or boosting aggregation helps to reduce the variance in any learner.
# * Decision trees are said to be associated with high variance due to this behavior.
# * Several decision trees which are generated in parallel, form the base learners of bagging technique.
# *  Data sampled with replacement is fed to these learners for training
# * The final prediction is the averaged output from all the learners.
# # Boosting
# * In boosting, the trees are built sequentially such that each subsequent tree aims to reduce the errors of the previous tree.
# * Each tree learns from its predecessors and updates the residual errors
# * Hence, the tree that grows next in the sequence will learn from an updated version of the residuals.
